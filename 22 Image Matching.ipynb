# %%
import numpy as np 
import matplotlib.pyplot as plt
import cv2

# %%
image1 = cv2.imread('images/eiphel1.png', 0)
image2 = cv2.imread('images/eiphel2.png', 0)

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.imshow(image1, cmap='gray')
plt.subplot(1,2,2) 
plt.imshow(image2, cmap='gray')

# %%
sift = cv2.SIFT_create()

# %%
keypoints_1, descriptors_1 = sift.detectAndCompute(image1,None)
keypoints_2, descriptors_2 = sift.detectAndCompute(image2,None)

len(keypoints_1), len(keypoints_2)
# Out:
# (332, 404)

# %%
#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(image1, keypoints_1, image2, keypoints_2, matches[:20], image2, flags=2)
plt.imshow(img3)

# %%
#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(image1, keypoints_1, image2, keypoints_2, matches[:40], image2, flags=2)
plt.imshow(img3)

# %%
#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(image1, keypoints_1, image2, keypoints_2, matches, image2, flags=2)
plt.imshow(img3)

# %%
len(matches)
# Out:
# 332

# %%
matches
# Out:
# [< cv2.DMatch 0000023714A12670>,
#  < cv2.DMatch 0000023714A84730>,
#  < cv2.DMatch 0000023714A12590>,
#  < cv2.DMatch 0000023714A846F0>,
#  < cv2.DMatch 0000023714A84750>,
#  < cv2.DMatch 0000023714A84710>,
#  < cv2.DMatch 0000023714A13730>,
#  < cv2.DMatch 0000023714A13070>,
#  < cv2.DMatch 0000023714A12710>,
#  < cv2.DMatch 0000023714A12B50>,
#  < cv2.DMatch 0000023714A13810>,
#  < cv2.DMatch 0000023714A12ED0>,
#  < cv2.DMatch 0000023714A12A30>,
#  < cv2.DMatch 0000023714A12E90>,
#  < cv2.DMatch 0000023714A12350>,
#  < cv2.DMatch 0000023714A12890>,
#  < cv2.DMatch 0000023714A13C70>,
#  < cv2.DMatch 0000023714A12F70>,
#  < cv2.DMatch 0000023714A13470>,
#  < cv2.DMatch 0000023714A13630>,
#  < cv2.DMatch 0000023714A13750>,
#  < cv2.DMatch 0000023714A84790>,
#  < cv2.DMatch 0000023714A12630>,
#  < cv2.DMatch 0000023714A13D10>,
#  < cv2.DMatch 0000023714A13490>,
#  < cv2.DMatch 0000023714A13BD0>,
#  < cv2.DMatch 0000023714A13C50>,
#  < cv2.DMatch 0000023714A12470>,
# ...
